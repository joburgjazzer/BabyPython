# %%
import os
os.getcwd()
# Out:
# 'D:\\GitHub\\BabyPython\\qe-spillover\\25002750'

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("max.csv")
# df = pd.read_csv("D:/tina/max.csv")

# %%
df.tail()
# Out:
#         Unnamed: 0   QE   seed   time  funds[0].exp.returns[currencies[1]]  \
# 428201      455058  800  109.0  246.0                            -0.000009
# 428202      455059  800  109.0  247.0                            -0.000009
# 428203      455060  800  109.0  248.0                            -0.000009
# 428204      455061  800  109.0  249.0                            -0.000009
# 428205      455062  800  109.0  250.0                            -0.000009
#
#         funds[0].exp.returns[portfolios[0]]  \
# 428201                            -0.000006
# 428202                            -0.000006
# 428203                            -0.000005
# 428204                            -0.000006
# 428205                            -0.000006
#
#         funds[0].exp.returns[portfolios[1]]  \
# 428201                            -0.000014
# 428202                            -0.000015
# 428203                            -0.000014
# 428204                            -0.000015
# 428205                            -0.000016
#
#         funds[3].exp.returns[currencies[0]]  \
# 428201                             0.000009
# 428202                             0.000009
# 428203                             0.000008
# 428204                             0.000009
# 428205                             0.000008
#
#         funds[3].exp.returns[portfolios[2]]  \
# 428201                         5.661216e-07
# 428202                         5.898508e-07
# 428203                         4.258002e-07
# 428204                         4.514451e-07
# 428205                         5.774382e-07
#
#         funds[3].exp.returns[portfolios[3]]  percentage_fx_rates.iloc[0,1]  \
# 428201                         1.563942e-06                       1.459039
# 428202                         1.606485e-06                       1.449320
# 428203                         8.784345e-07                       1.419389
# 428204                         1.000814e-06                       1.442404
# 428205                         1.596704e-06                       1.437892
#
#         percentage_portfolio0  percentage_portfolio1  percentage_portfolio2  \
# 428201               0.803472               4.431372              -0.076765
# 428202               0.823159               4.670770              -0.080033
# 428203               0.768552               4.230991              -0.057828
# 428204               0.810921               4.622141              -0.061288
# 428205               0.817832               4.826554              -0.078399
#
#         percentage_portfolio3  cal  dom_bond_yields_perQE  dom_bond_yields
# 428201              -0.425421  max              -0.017460       -13.967948
# 428202              -0.438632  max              -0.017889       -14.311369
# 428203              -0.241688  max              -0.016687       -13.349499
# 428204              -0.274776  max              -0.017609       -14.087519
# 428205              -0.438431  max              -0.017769       -14.214966

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'QE', 'seed', 'time',
#        'funds[0].exp.returns[currencies[1]]',
#        'funds[0].exp.returns[portfolios[0]]',
#        'funds[0].exp.returns[portfolios[1]]',
#        'funds[3].exp.returns[currencies[0]]',
#        'funds[3].exp.returns[portfolios[2]]',
#        'funds[3].exp.returns[portfolios[3]]', 'percentage_fx_rates.iloc[0,1]',
#        'percentage_portfolio0', 'percentage_portfolio1',
#        'percentage_portfolio2', 'percentage_portfolio3', 'cal',
#        'dom_bond_yields_perQE', 'dom_bond_yields'],
#       dtype='object')

# %%
head = df.head()
head.shape
head.index
# Out:
# (5, 18)
# RangeIndex(start=0, stop=5, step=1)

# %%
cols = head.columns
# head[:, 'time']
df.describe()
# Out:
#           Unnamed: 0             QE           seed           time  \
# count  428206.000000  428206.000000  428206.000000  428206.000000
# mean   238676.076788     861.987104      54.048066     125.000000
# std    127344.113073     868.428047      32.147759      72.456968
# min      2510.000000      20.000000       0.000000       0.000000
# 25%    133908.250000      80.000000      26.000000      62.000000
# 50%    240959.500000     400.000000      53.000000     125.000000
# 75%    348010.750000    1600.000000      83.000000     188.000000
# max    455062.000000    2600.000000     109.000000     250.000000
#
#        funds[0].exp.returns[currencies[1]]  \
# count                         4.282060e+05
# mean                         -3.736983e-06
# std                           3.656835e-06
# min                          -1.360437e-05
# 25%                          -7.055633e-06
# 50%                          -3.680285e-06
# 75%                          -5.279662e-07
# max                           1.044147e-05
#
#        funds[0].exp.returns[portfolios[0]]  \
# count                         4.282060e+05
# mean                         -3.202180e-06
# std                           3.190926e-06
# min                          -2.012739e-05
# 25%                          -5.581117e-06
# 50%                          -2.743594e-06
# 75%                          -7.121473e-07
# max                           7.043010e-06
#
#        funds[0].exp.returns[portfolios[1]]  \
# count                         4.282060e+05
# mean                         -6.641484e-06
# std                           1.042837e-05
# min                          -4.940515e-05
# 25%                          -1.301518e-05
# 50%                          -5.369242e-06
# 75%                          -4.326434e-08
# max                           7.732813e-05
#
#        funds[3].exp.returns[currencies[0]]  \
# count                         4.282060e+05
# mean                          3.684718e-06
# std                           3.605671e-06
# min                          -1.026686e-05
# 25%                           5.151515e-07
# 50%                           3.617666e-06
# 75%                           6.963756e-06
# max                           1.335105e-05
#
#        funds[3].exp.returns[portfolios[2]]  \
# count                         4.282060e+05
# mean                          2.262990e-08
# std                           4.302739e-07
# min                          -2.059578e-06
# 25%                          -2.299059e-07
# 50%                           2.611465e-08
# 75%                           2.917459e-07
# max                           1.606529e-06
#
#        funds[3].exp.returns[portfolios[3]]  percentage_fx_rates.iloc[0,1]  \
# count                         4.282060e+05                  428206.000000
# mean                          5.611596e-07                       0.622244
# std                           2.501872e-06                       0.608905
# min                          -8.819868e-06                      -1.710891
# 25%                          -1.113178e-06                       0.086948
# 50%                           4.093177e-07                       0.610156
# 75%                           2.007519e-06                       1.175141
# max                           1.521782e-05                       2.271666
#
#        percentage_portfolio0  percentage_portfolio1  percentage_portfolio2  \
# count          428206.000000          428206.000000          428206.000000
# mean                0.465201               2.262943              -0.003052
# std                 0.464264               3.423004               0.058575
# min                -1.011055             -18.530819              -0.216644
# 25%                 0.102731               0.013871              -0.039681
# 50%                 0.396790               1.740736              -0.003555
# 75%                 0.810120               4.327289               0.031276
# max                 2.977718              17.811906               0.283034
#
#        percentage_portfolio3  dom_bond_yields_perQE  dom_bond_yields
# count          428206.000000          428206.000000    428206.000000
# mean               -0.153746              -0.013042        -8.005450
# std                 0.692825               0.059268         7.977314
# min                -4.279763              -0.599620       -50.318471
# 25%                -0.553663              -0.022504       -13.952793
# 50%                -0.113352              -0.009973        -6.858984
# 75%                 0.307158              -0.005039        -1.780368
# max                 2.654151               0.730511        17.607526

# %% [markdown]
# ## Frequencies
#
# To get frequencies...
#
# -
# -
# -

# %%
fQE = df['QE'].value_counts().sort_index().to_frame('QE')
fQE['pct'] = 100 * fQE['QE'] / fQE['QE'].sum()
fQE
# Out:
#          QE       pct
# 20    26857  6.271981
# 40    26857  6.271981
# 60    26857  6.271981
# 80    26857  6.271981
# 100   26857  6.271981
# 150   26857  6.271981
# 200   26857  6.271981
# 400   26857  6.271981
# 600   26857  6.271981
# 800   26857  6.271981
# 1200  26606  6.213365
# 1600  26606  6.213365
# 1800  26606  6.213365
# 2000  26606  6.213365
# 2200  26606  6.213365
# 2600  26606  6.213365

# %%
fQE = df['QE'].value_counts().sort_index().to_frame('QE')
fQE['pct'] = 100 * fQE['QE'] / fQE['QE'].sum()
fQE

# %%
C:\Program Files\Intel\WiFi\bin\;
    C:\Program Files\Common Files\Intel\WirelessCommon\;
        C:\Users\a120815\AppData\Local\GitHubDesktop\bin
